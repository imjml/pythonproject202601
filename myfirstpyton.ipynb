# %%
print("Hello python")
print("Hello python")
# Out:
# Hello python
# Hello python

# %%
# 깃헙에 로컬에서 작업한 내용을 올려보자.

# %%
print("안녕")
# Out:
# 안녕하세요

# %%
print("안녕하세요 저는 이재모입니다")
# Out:
# 안녕하세요 저는 이재모입니다
